# %%
import pandas as pd

# %%
processed_dataset_path = "/home/magnus9102/Mostafa/Py/Github/data-science/mostafa_vahdani_bachelor_project/data/interim/1-2-final_flight_tickets_dataset.csv"

# %%
df = pd.read_csv(processed_dataset_path)

# %%
# Correlation Matrix
df.corr()
# Out:
#                             departure_city_0  departure_city_1  \
# departure_city_0                    1.000000         -0.139693
# departure_city_1                   -0.139693          1.000000
# departure_city_2                    0.069367          0.088045
# departure_city_3                   -0.140324          0.015302
# departure_city_4                    0.309874         -0.043053
# departure_city_5                   -0.074618         -0.393272
# arrival_city_0                     -0.023382         -0.065996
# arrival_city_1                     -0.039398         -0.045872
# arrival_city_2                     -0.057719          0.197549
# arrival_city_3                     -0.075074         -0.085014
# arrival_city_4                      0.044571         -0.380013
# arrival_city_5                      0.064246          0.271496
# company_name_0                     -0.006733         -0.001890
# company_name_1                      0.133057          0.188854
# ...

# %%
# Covariance Matrix
df.cov()

# %%
df.describe()
